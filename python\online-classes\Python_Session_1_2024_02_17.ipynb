# %% [markdown]
# <a href="https://colab.research.google.com/github/GitRudra/datascienceAI/blob/main/python%5Conline-classes%5CPython_Session_1_2024_02_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
#interpreter
#
# bin(135)
hex(135)
# Out:
# '0x87'

# %%
num=10
print(num, id(num))
# Changing value of a vaiable allocates a brand new memory with the value and the vairable points to the new address
num=20
print(num, id(num))
#Python is a dynamic programing language
print(25.6, id(25.6))
# Out:
# 10 139207900217872
# 20 139207900218192
# 25.6 139206631846512

# %% [markdown]
# ### **Python is memory efficient & slowest language **

# %% [markdown]
# Explicit Interning

# %%
import sys
fname =  sys.intern('Rudra Pal')
print(fname)
# Out:
# Rudra Pal

# %%
print(print('rudra'))
# Out:
# rudra
# None

# %%
age=100
is_eligible = (age > 18) and True and 'vasanth'
print(is_eligible)
# Out:
# vasanth

# %%
print(13 & 7)
print(21 & 18)
print(13 | 7)
# Out:
# 5
# 16
# 15

# %% [markdown]
# # **Strings**

# %%
# strings -> '', "", """ """, ''' '''
print("Sachin Tendulkar is a 'Good' cricketer")
# Out:
# Sachin Tendulkar is a 'Good' cricketer

# %%
#user input
name: str = input("Name")
age: int = input("Age")
print('name: ', name)
print('age: ', age)
# Out:
# Name34
# Agedrr
# name:  34
# age:  drr
